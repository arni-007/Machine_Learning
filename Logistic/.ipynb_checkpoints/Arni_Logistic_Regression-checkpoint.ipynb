# %%
#Logistic Regression

#Unlike linear regression which predicts continuous values it predicts the probability that an input belongs to a specific class.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"framingham.csv")
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df=df.dropna()
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4231     1   58        3.0              0         0.0     0.0
# 4232     1   68        1.0              0         0.0     0.0
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df = df.sample(frac=1, random_state=42).reset_index(drop=True)  #it shuffles the dataset

# %%
X = df.drop("TenYearCHD", axis=1)
y = df["TenYearCHD"]

X = (X - np.mean(X, axis=0)) / np.std(X, axis=0)
X
# Out:
#           male       age  education  currentSmoker  cigsPerDay    BPMeds  \
# 0    -0.892997 -0.298768   0.019795      -0.978352   -0.757068 -0.176951
# 1    -0.892997 -1.817466   0.019795      -0.978352   -0.757068 -0.176951
# 2    -0.892997  2.037691   0.997773       1.022127   -0.673156 -0.176951
# 3    -0.892997 -0.882882   0.019795       1.022127   -0.589244 -0.176951
# 4     1.119825 -0.065122   0.019795       1.022127    3.438535 -0.176951
# ...        ...       ...        ...            ...         ...       ...
# 3651  1.119825 -1.350174   0.019795       1.022127    0.501613 -0.176951
# 3652 -0.892997  0.986285   0.019795       1.022127   -0.505331 -0.176951
# 3653  1.119825 -0.298768   1.975752      -0.978352   -0.757068 -0.176951
# 3654  1.119825  0.402170   0.019795      -0.978352   -0.757068 -0.176951
# 3655  1.119825  0.051701   0.019795      -0.978352   -0.757068 -0.176951
#
#       prevalentStroke  prevalentHyp  diabetes   totChol     sysBP     diaBP  \
# ...

# %%
split_index = int(0.8 * len(X))
X_train = X[:split_index]
X_test = X[split_index:]

y_train = y[:split_index]
y_test = y[split_index:]

X_train = np.c_[np.ones(X_train.shape[0]), X_train]
X_test = np.c_[np.ones(X_test.shape[0]), X_test]

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# %%
m, n = X_train.shape
weights = np.zeros(n)

# %%
learning_rate = 0.001
epochs = 5000

# %%
for i in range(epochs):
    
    z = np.dot(X_train, weights)       #This gives our (XW) used in our logistic regression
    predictions = sigmoid(z)

    gradient = (1/m) * np.dot(X_train.T, (predictions - y_train))    #Transverse bcz y and prediction are in the shape (m,) and the shape of X is (m,n)

    weights = weights - learning_rate * gradient

# %%
z_test = np.dot(X_test, weights)
y_pred = sigmoid(z_test)
y_pred = (y_pred >= 0.3).astype(int)

# %%
TP = np.sum((y_pred == 1) & (y_test == 1))
TN = np.sum((y_pred == 0) & (y_test == 0))
FP = np.sum((y_pred == 1) & (y_test == 0))
FN = np.sum((y_pred == 0) & (y_test == 1))

# %%
accuracy = (TP + TN) / (TP + TN + FP + FN)

# %%
print("TP:", TP) 
print("TN:", TN)
print("FP:", FP) 
print("FN:", FN)
# Out:
# TP: 58
# TN: 451
# FP: 177
# FN: 46

# %%
precision = TP / (TP + FP)
recall = TP / (TP + FN)
specificity = TN / (TN + FP)
f1_score = 2 * (precision * recall) / (precision + recall)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall (Sensitivity):", recall)
print("Specificity:", specificity)
print("F1 Score:", f1_score)
# Out:
# Accuracy: 0.6953551912568307
# Precision: 0.24680851063829787
# Recall (Sensitivity): 0.5576923076923077
# Specificity: 0.7181528662420382
# F1 Score: 0.3421828908554572

# %%
import matplotlib.pyplot as plt
metrics = ["Accuracy","Precision","Recall","Specificity","F1 Score"]
values = [accuracy, precision, recall, specificity, f1_score]

plt.figure(figsize=(8,4))
bar=plt.bar(metrics, values, color="lavender", edgecolor="black")
plt.bar_label(bar)

plt.title("Model Performance Metrics")
plt.ylabel("Score")
plt.ylim(0,1)

plt.show()

# %%
import seaborn as sns

cm = np.array([[TN, FP],
               [FN, TP]])

sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

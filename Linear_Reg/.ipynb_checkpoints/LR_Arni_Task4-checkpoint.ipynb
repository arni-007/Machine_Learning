# %%
import numpy as np
import pandas as pd

train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

y_train = train["Price"].astype(float).values
y_test = test["Price"].astype(float).values

train = train.drop("Price", axis=1)
test = test.drop("Price", axis=1)

train = pd.get_dummies(train, drop_first=True)
test = pd.get_dummies(test, drop_first=True)

# Align test columns to train
test = test.reindex(columns=train.columns, fill_value=0)

train = train.fillna(train.mean())
test = test.fillna(test.mean())

X_train = train.astype(float).values
X_test = test.astype(float).values

mean = X_train.mean(axis=0)
std = X_train.std(axis=0)

std[std == 0] = 1  # avoid division by zero

X_train = (X_train - mean) / std
X_test = (X_test - mean) / std

X_train = np.c_[np.ones(X_train.shape[0]), X_train]
X_test = np.c_[np.ones(X_test.shape[0]), X_test]

m, n = X_train.shape
theta = np.zeros(n)

learning_rate = 0.01
iterations = 1000

for i in range(iterations):
    y_pred_train = X_train @ theta
    error = y_pred_train - y_train
    gradient = (1/m) * (X_train.T @ error)
    theta = theta - learning_rate * gradient

    if i % 100 == 0:
        loss = (1/(2*m)) * np.sum(error**2)
        print(f"Iteration {i}, Loss: {loss:.4f}")

y_pred = X_test @ theta

mse = np.mean((y_test - y_pred) ** 2)

ss_total = np.sum((y_test - np.mean(y_test)) ** 2)
ss_residual = np.sum((y_test - y_pred) ** 2)
r2 = 1 - (ss_residual / ss_total)

print("\nFinal Results:")
print("Mean Squared Error (MSE):", mse)
print("R² Score:", r2)
# Out:
# Iteration 0, Loss: 107.9030
# Iteration 100, Loss: 8.4250
# Iteration 200, Loss: 2.6790
# Iteration 300, Loss: 1.8915
# Iteration 400, Loss: 1.7601
# Iteration 500, Loss: 1.7229
# Iteration 600, Loss: 1.7026
# Iteration 700, Loss: 1.6877
# Iteration 800, Loss: 1.6757
# Iteration 900, Loss: 1.6657
#
# Final Results:
# Mean Squared Error (MSE): 28.212765635467903
# R² Score: 0.7724385778074956
